# %% [markdown]
# # Tutorial 3: Data Visualizations
# [![Binder](https://mybinder.org/badge_logo.svg)](https://mybinder.org/v2/gh/pyinat/pyinaturalist/main?filepath=examples%2FTutorial_3_Data_Visualizations.ipynb)
#
# This notebook will show you a few basic visualizations you can make with your own observation data.
#
# We'll do this with [Pandas](https://pandas.pydata.org/docs/getting_started/index.html) and [Altair](https://altair-viz.github.io). Don't worry if you're not familiar with those tools, this is just to demonstrate the kinds of things you can do with your data.

# %%
from datetime import datetime, timedelta

import altair as alt
import pandas as pd
from dateutil.relativedelta import relativedelta
from pyinaturalist import Observation, enable_logging, get_observations, pprint
from rich import print

enable_logging()

# %% [markdown]
# ## Observation data
# We'll start with all of your own observation data from the last 3 years:

# %%
# Replace with your own username
USERNAME = 'jkcook'

start_date = datetime.now() - timedelta(365 * 3)
response = get_observations(user_id=USERNAME, d1=start_date, page='all')
my_observations = Observation.from_json_list(response)
pprint(my_observations[:10])
# Out:
#
#   ID         Taxon ID   Taxon                     Observed on    User     Location
#  ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━
#   30688807   78444      🌱 Species: Peritoma      Aug 12, 2019   jkcook   Johnston, IA, USA
#                         serrulata (Rocky
#                         Mountain beeplant)
#   30688955   47912      🌱 Species: Asclepias     Aug 12, 2019   jkcook   Johnston, IA, USA
#                         tuberosa (butterfly
#                         milkweed)
#   30689111   60251      🌱 Species: Verbena       Aug 12, 2019   jkcook   Johnston, IA, USA
#                         hastata (blue vervain)
#   30689221   121968     🌽 Species: Andropogon    Aug 12, 2019   jkcook   Johnston, IA, USA
#                         gerardi (big bluestem)
#   30689306   121968     🌽 Species: Andropogon    Aug 12, 2019   jkcook   Johnston, IA, USA
#                         gerardi (big bluestem)
#   30689425   128701     🌱 Species: Desmanthus    Aug 12, 2019   jkcook   Johnston, IA, USA
#                         illinoensis (Illinois
#                         bundleflower)
#   30689463   121976     🌻 Species: Silphium      Aug 12, 2019   jkcook   Johnston, IA, USA
#                         laciniatum (compass
#                         plant)
#   30689506   136376     🌻 Species: Rudbeckia     Aug 12, 2019   jkcook   Johnston, IA, USA
#                         triloba (Brown-eyed
#                         Susan)
#   30689603   121976     🌻 Species: Silphium      Aug 12, 2019   jkcook   Johnston, IA, USA
#                         laciniatum (compass
#                         plant)
#   30689780   81594      🌾 Species: Elymus        Aug 12, 2019   jkcook   Johnston, IA, USA
#                         hystrix (bottlebrush
#                         grass)

# %% [markdown]
# ## Basic historgam
# Next, let's make a simple histogram to show your observations over time.
#
# Start by putting your observations into a DataFrame to make them easier to work with:

# %%
source = pd.DataFrame([{'date': o.observed_on.isoformat()} for o in my_observations])

# %% [markdown]
# And then display it as a bar chart:

# %%
(
    alt.Chart(source)
    .mark_bar()
    .properties(width=700, height=500)
    .encode(
        x='yearmonth(date):T',
        y=alt.Y(
            'count()',
            scale=alt.Scale(type='log'),
            axis=alt.Axis(title='Number of observations'),
        ),
    )
)
# Out:
# alt.Chart(...)
# <div id="altair-viz-4df0bdeec23e4a8a8ccbb0c95fad0e8e"></div>
# <script type="text/javascript">
#   (function(spec, embedOpt){
#     let outputDiv = document.currentScript.previousElementSibling;
#     if (outputDiv.id !== "altair-viz-4df0bdeec23e4a8a8ccbb0c95fad0e8e") {
#       outputDiv = document.getElementById("altair-viz-4df0bdeec23e4a8a8ccbb0c95fad0e8e");
#     }
#     const paths = {
#       "vega": "https://cdn.jsdelivr.net/npm//vega@5?noext",
#       "vega-lib": "https://cdn.jsdelivr.net/npm//vega-lib?noext",
#       "vega-lite": "https://cdn.jsdelivr.net/npm//vega-lite@4.8.1?noext",
#       "vega-embed": "https://cdn.jsdelivr.net/npm//vega-embed@6?noext",
#     };
#
#     function loadScript(lib) {
#       return new Promise(function(resolve, reject) {
#         var s = document.createElement('script');
#         s.src = paths[lib];
#         s.async = true;
#         s.onload = () => resolve(paths[lib]);
#         s.onerror = () => reject(`Error loading script: ${paths[lib]}`);
#         document.getElementsByTagName("head")[0].appendChild(s);
#       });
#     }
#
#     function showError(err) {
#       outputDiv.innerHTML = `<div class="error" style="color:red;">${err}</div>`;
#       throw err;
#     }
#
#     function displayChart(vegaEmbed) {
#       vegaEmbed(outputDiv, spec, embedOpt)
#         .catch(err => showError(`Javascript Error: ${err.message}<br>This usually means there's a typo in your chart specification. See the javascript console for the full traceback.`));
#     }
#
#     if(typeof define === "function" && define.amd) {
#       requirejs.config({paths});
#       require(["vega-embed"], displayChart, err => showError(`Error loading script: ${err.message}`));
#     } else if (typeof vegaEmbed === "function") {
#       displayChart(vegaEmbed);
#     } else {
#       loadScript("vega")
#         .then(() => loadScript("vega-lite"))
#         .then(() => loadScript("vega-embed"))
#         .catch(showError)
#         .then(() => displayChart(vegaEmbed));
#     }
#   })({"config": {"view": {"continuousWidth": 400, "continuousHeight": 300}}, "data": {"name": "data-546f1561168adf5701ff5eb95d0cda45"}, "mark": "bar", "encoding": {"x": {"type": "temporal", "field": "date", "timeUnit": "yearmonth"}, "y": {"type": "quantitative", "aggregate": "count", "axis": {"title": "Number of observations"}, "scale": {"type": "log"}}}, "height": 500, "width": 700, "$schema": "https://vega.github.io/schema/vega-lite/v4.8.1.json", "datasets": {"data
-06:00"}, {"date": "2019-08-13T19:45:32-06:00"}, {"date": "2019-08-13T19:47:23-06:00"}, {"date": "2019-08-13T19:50:14-06:00"}, {"date": "2019-08-13T19:55:52-06:00"}, {"date": "2019-08-13T19:57:09-06:00"}, {"date": "2019-08-13T20:05:08-06:00"}, {"date": "2019-08-12T18:14:00-06:00"}, {"date": "2019-07-04T11:38:18-06:00"}, {"date": "2019-07-06T20:39:59-06:00"}, {"date": "2019-08-14T10:24:35-06:00"}, {"date": "2019-08-14T10:25:54-06:00"}, {"date": "2019-08-14T10:28:09-06:00"}, {"date": "2019-08-14T10:29:16-06:00"}, {"date": "2019-08-14T10:31:24-06:00"}, {"date": "2019-08-14T10:33:41-06:00"}, {"date": "2019-08-14T10:34:39-06:00"}, {"date": "2019-08-14T10:35:57-06:00"}, {"date": "2019-08-14T ...

# %% [markdown]
# ## Histogram by iconic taxon
# To show a bit more information, let's break down the observations by category (iconic taxon):

# %%
source = pd.DataFrame(
    [
        {'date': o.observed_on.isoformat(), 'iconic_taxon': o.taxon.iconic_taxon_name}
        for o in my_observations
    ]
)
(
    alt.Chart(source)
    .mark_bar()
    .properties(width=700, height=500)
    .encode(
        x='yearmonth(date):T',
        y=alt.Y(
            'count()',
            scale=alt.Scale(type='symlog'),
            axis=alt.Axis(title='Number of observations'),
        ),
        color='iconic_taxon',
    )
)
# Out:
# alt.Chart(...)
# <div id="altair-viz-c134a2039d27476d8c4e651ecfc8cab7"></div>
# <script type="text/javascript">
#   (function(spec, embedOpt){
#     let outputDiv = document.currentScript.previousElementSibling;
#     if (outputDiv.id !== "altair-viz-c134a2039d27476d8c4e651ecfc8cab7") {
#       outputDiv = document.getElementById("altair-viz-c134a2039d27476d8c4e651ecfc8cab7");
#     }
#     const paths = {
#       "vega": "https://cdn.jsdelivr.net/npm//vega@5?noext",
#       "vega-lib": "https://cdn.jsdelivr.net/npm//vega-lib?noext",
#       "vega-lite": "https://cdn.jsdelivr.net/npm//vega-lite@4.8.1?noext",
#       "vega-embed": "https://cdn.jsdelivr.net/npm//vega-embed@6?noext",
#     };
#
#     function loadScript(lib) {
#       return new Promise(function(resolve, reject) {
#         var s = document.createElement('script');
#         s.src = paths[lib];
#         s.async = true;
#         s.onload = () => resolve(paths[lib]);
#         s.onerror = () => reject(`Error loading script: ${paths[lib]}`);
#         document.getElementsByTagName("head")[0].appendChild(s);
#       });
#     }
#
#     function showError(err) {
#       outputDiv.innerHTML = `<div class="error" style="color:red;">${err}</div>`;
#       throw err;
#     }
#
#     function displayChart(vegaEmbed) {
#       vegaEmbed(outputDiv, spec, embedOpt)
#         .catch(err => showError(`Javascript Error: ${err.message}<br>This usually means there's a typo in your chart specification. See the javascript console for the full traceback.`));
#     }
#
#     if(typeof define === "function" && define.amd) {
#       requirejs.config({paths});
#       require(["vega-embed"], displayChart, err => showError(`Error loading script: ${err.message}`));
#     } else if (typeof vegaEmbed === "function") {
#       displayChart(vegaEmbed);
#     } else {
#       loadScript("vega")
#         .then(() => loadScript("vega-lite"))
#         .then(() => loadScript("vega-embed"))
#         .catch(showError)
#         .then(() => displayChart(vegaEmbed));
#     }
#   })({"config": {"view": {"continuousWidth": 400, "continuousHeight": 300}}, "data": {"name": "data-8131773a4ab9f24f2807d9e67b7ee4c9"}, "mark": "bar", "encoding": {"color": {"type": "nominal", "field": "iconic_taxon"}, "x": {"type": "temporal", "field": "date", "timeUnit": "yearmonth"}, "y": {"type": "quantitative", "aggregate": "count", "axis": {"title": "Number of observations"}, "scale": {"type": "symlog"}}}, "height": 500, "width": 700, "$schema": "https://vega.github.io/schema/vega-lite/v4.8.1.json", "datasets": {"data-8131773a4ab9f24f2807d9e67b7ee4c9": [{"date": "2019-08-12T10:16:00+00:00", "iconic_taxon": "Plantae"}, {"date": "2019-08-12T10:24:00+00:00", "iconic_taxon": "Plantae"}, {"date": "2019-08-12T10:26:00+00:00", "iconic_taxon": "Plantae"}, {"date": "2019-08-12T10:29:00+00:00", "iconic_taxon": "Plantae"}, {"date": "2019-08-12T10:31:00+00:00", "iconic_taxon": "Plantae"}, {"date": "2019-08-12T10:31:00+00:00", "iconic_taxon": "Plantae"}, {"date": "2019-08-12T10:34:00+00:00", "iconic_taxon": "Plantae"}, {"date": "2019-08-12T10:35:00+00:00", "iconic_taxon": "Plantae"}, {"date": "2019-08-12T10:36:00+00:00", "iconic_taxon": "Plantae"}, {"date": "2019-08-12T10:38:00+00:00", "iconic_taxon": "Plantae"}, {"date": "2019-08-12T10:46:00+00:00", "iconic_taxon": "Plantae"}, {"date": "2019-08-12T10:47:00+00:00", "iconic_taxon": "Plantae"}, {"date": "2019-08-12T10:48:00+00:00", "iconic_taxon": "Plantae"}, {"date": "2019-08-12T10:49:00+00:00", "iconic_taxon": "Plantae"}, {"date": "2019-08-12T18:40:00-06:00", "iconic_taxon": "Plantae"}, {"date": "2019-08-12T18:41:00-06:00", "iconic_taxon": "Plantae"}, {"date": "2019-08-12T18:41:00-06:00", "iconic_taxon": "Plantae"}, {"date": "2019-08-12T18:36:00-06:00", "iconic_taxon": "Insecta"}, {"date": "2019-08-12T18:11:00-06:00", "iconic_taxon": "Insecta"}, {"date": "2019-08-12T18:13:00-06:00", "iconic_taxon": "Insecta"}, {"date": "2019-08-12T18:36:00-06:00", "iconic_taxon": "Plantae"}, {"date": "2019-08-12T18:08:03-06:00", "iconic_taxon": "Plantae"}, {"date": "2019-08-12T18:10:05-06:00", "iconic_taxon": "Plantae"}, {"date": "2019-08-12T18:15:39-06:00", "iconic_taxon": "Plantae"}, {"date": "2019-08-12T18:17:53-06:00", "iconic_taxon": "Plantae"}, {"date": "2019-08-12T18:18:50-06:00", "iconic_taxon": "Plantae"}, {"date": "2019-08-12T18:35:00-06:00", "iconic_taxon": "Plantae"}, {"date": "2019-08-12T18:20:23-06:00", "iconic_taxon": "Plantae"}, {"date": "2019-08-12T18:21:26-06:00", "iconic_taxon": "Plantae"}, {"date": "2019-08-12T18:33:00-06:00", "iconic_taxon": "Plantae"}, {"date": "2019-08-12T18:31:00-06:00", "iconic_taxon": "Plantae"}, {"date": "2019-08-12T18:29:00-06:00", "iconic_taxon": "Plantae"}, {"date": "2019-08-12T18:26:00-06:00", "iconic_taxon": "Plantae"}, {"date": "2019-08-12T18:26:00-06:00", "iconic_taxon": "Plantae"}, {"date": "2019-08-12T18:25:00-06:00", "iconic_taxon": "Plantae"}, {"date": "2019-08-12T18:24:00-06:00", "iconic_taxon": "Plantae"}, {"date": "2019-08-12T18:12:00-06:00", "iconic_taxon": "Plantae"}, {"date": "2019-08-12T18:30:00-06:00", "iconic_taxon": "Plantae"}, {"date": "2019-08-13T13:16:01-06:00", "iconic_taxon": "Fungi"}, {"date": "2019-08-13T18:16:42-06:00", "iconic_taxon": "Plantae"}, {"date": "2019-08-13T18:17:35-06:00", "iconic_taxon": "Plantae"}, {"date": "2019-08-13T18:26:32-06:00", "iconic_taxon": "Plantae"}, {"date": "2019-08-13T18:27:24-06:00", "iconic_taxon": "Plantae"}, {"date": "2019-08-13T18:28:29-06:00", "iconic_taxon": "Plantae"}, {"date": "2019-08-13T18:29:28-06:00", "iconic_taxon": "Plantae"}, {"date": "2019-08-13T18:30:25-06:00", "iconic_taxon": "Plantae"}, {"date": "2019-08-13T18:37:50-06:00", "iconic_taxon": "Plantae"}, {"date": "2019-08-13T18:40:19-06:00", "iconic_taxon": "Plantae"}, {"date": "2019-08-13T18:43:53-06:00", "iconic_taxon": "Plantae"}, {"date": "2019-08-13T18:45:54-06:00", "iconic_taxon": "Plantae"}, {"date": "2019-08-13T18:48:17-06:00", "iconic_taxon": "Plantae"}, {"date": "2019-08-13T18:54:53-06:00", "iconic_taxon": "Plantae"}, {"da ...

# %% [markdown]
# ## Observation map
# Next, we can show the observations on a map. **Note:** This example only shows observations in the United States.
#
# First, get the coordinates for all your observations, skipping any that are missing locatino info:

# %%
source = pd.DataFrame(
    [
        {
            'latitude': o.location[0],
            'longitude': o.location[1],
            'iconic_taxon': o.taxon.iconic_taxon_name,
        }
        for o in my_observations
        if o.location
    ]
)

# %% [markdown]
# Then add the base layer. This example uses the `us_10m` dataset from [vega-datasets](https://github.com/vega/vega-datasets):

# %%
from vega_datasets import data

states = alt.topo_feature(data.us_10m.url, feature='states')
background = (
    alt.Chart(states)
    .mark_geoshape(fill='lightgray', stroke='white')
    .properties(width=850, height=500)
    .project('albersUsa')
)

# %% [markdown]
# And finally, add your observation locations:

# %%
points = (
    alt.Chart(source)
    .mark_circle()
    .encode(
        longitude='longitude:Q',
        latitude='latitude:Q',
    )
)

# Show the combined background + points
background + points
# Out:
# alt.LayerChart(...)
# <div id="altair-viz-e970c949744f4a5096739f726fdd693e"></div>
# <script type="text/javascript">
#   (function(spec, embedOpt){
#     let outputDiv = document.currentScript.previousElementSibling;
#     if (outputDiv.id !== "altair-viz-e970c949744f4a5096739f726fdd693e") {
#       outputDiv = document.getElementById("altair-viz-e970c949744f4a5096739f726fdd693e");
#     }
#     const paths = {
#       "vega": "https://cdn.jsdelivr.net/npm//vega@5?noext",
#       "vega-lib": "https://cdn.jsdelivr.net/npm//vega-lib?noext",
#       "vega-lite": "https://cdn.jsdelivr.net/npm//vega-lite@4.8.1?noext",
#       "vega-embed": "https://cdn.jsdelivr.net/npm//vega-embed@6?noext",
#     };
#
#     function loadScript(lib) {
#       return new Promise(function(resolve, reject) {
#         var s = document.createElement('script');
#         s.src = paths[lib];
#         s.async = true;
#         s.onload = () => resolve(paths[lib]);
#         s.onerror = () => reject(`Error loading script: ${paths[lib]}`);
#         document.getElementsByTagName("head")[0].appendChild(s);
#       });
#     }
#
#     function showError(err) {
#       outputDiv.innerHTML = `<div class="error" style="color:red;">${err}</div>`;
#       throw err;
#     }
#
#     function displayChart(vegaEmbed) {
#       vegaEmbed(outputDiv, spec, embedOpt)
#         .catch(err => showError(`Javascript Error: ${err.message}<br>This usually means there's a typo in your chart specification. See the javascript console for the full traceback.`));
#     }
#
#     if(typeof define === "function" && define.amd) {
#       requirejs.config({paths});
#       require(["vega-embed"], displayChart, err => showError(`Error loading script: ${err.message}`));
#     } else if (typeof vegaEmbed === "function") {
#       displayChart(vegaEmbed);
#     } else {
#       loadScript("vega")
#         .then(() => loadScript("vega-lite"))
#         .then(() => loadScript("vega-embed"))
#         .catch(showError)
#         .then(() => displayChart(vegaEmbed));
#     }
#   })({"config": {"view": {"continuousWidth": 400, "continuousHeight": 300}}, "layer": [{"data": {"url": "https://cdn.jsdelivr.net/npm/vega-datasets@v1.29.0/data/us-10m.json", "format": {"feature": "states", "type": "topojson"}}, "mark": {"type": "geoshape", "fill": "lightgray", "stroke": "white"}, "height": 500, "projection": {"type": "albersUsa"}, "width": 850}, {"data": {"name": "data-6603dadda7953444f117127450068ad5"}, "mark": "circle", "encoding": {"latitude": {"field": "latitude", "type": "quantitative"}, "longitude": {"field": "longitude", "type": "quantitative"}}}], "$schema": "https://vega.github.io/schema/vega-lite/v4.8.1.json", "datasets": {"data-6603dadda7953444f117127450068ad5": [{"latitude": 41.67206561, "longitude": -93.72957587, "iconic_taxon": "Plantae"}, {"latitude": 41.67083724, "longitude": -93.72967602, "iconic_taxon": "Plantae"}, {"latitude": 41.67022214, "longitude": -93.72953544, "iconic_taxon": "Plantae"}, {"latitude": 41.66977213, "longitude": -93.72976124, "iconic_taxon": "Plantae"}, {"latitude": 41.6700397, "longitude": -93.73032141, "iconic_taxon": "Plantae"}, {"latitude": 41.66959702, "longitude": -93.73063287, "iconic_taxon": "Plantae"}, {"latitude": 41.66954439, "longitude": -93.73064545, "iconic_taxon": "Plantae"}, {"latitude": 41.66913939, "longitude": -93.73026902, "iconic_taxon": "Plantae"}, {"latitude": 41.66899238, "longitude": -93.73047934, "iconic_taxon": "Plantae"}, {"latitude": 41.66899503, "longitude": -93.73055338, "iconic_taxon": "Plantae"}, {"latitude": 41.66970354, "longitude": -93.7300163, "iconic_taxon": "Plantae"}, {"latitude": 41.67018301, "longitude": -93.72952336, "iconic_taxon": "Plantae"}, {"latitude": 41.67098202, "longitude": -93.72979941, "iconic_taxon": "Plantae"}, {"latitude": 41.67118919, "longitude": -93.72948673, "iconic_taxon": "Plantae"}, {"latitude": 41.670837, "longitude": -93.729676, "iconic_taxon": "Plantae"}, {"latitude": 41.670837, "longitude": -93.729676, "iconic_taxon": "Plantae"}, {"latitude": 41.670837, "longitude": -93.729676, "iconic_taxon": "Plantae"}, {"latitude": 41.67, "longitude": -93.7303, "iconic_taxon": "Insecta"}, {"latitude": 41.67, "longitude": -93.7303, "iconic_taxon": "Insecta"}, {"latitude": 41.67, "longitude": -93.7303, "iconic_taxon": "Insecta"}, {"latitude": 41.67, "longitude": -93.7303, "iconic_taxon": "Plantae"}, {"latitude": 41.6714582, "longitude": -93.7295032, "iconic_taxon": "Plantae"}, {"latitude": 41.67107655, "longitude": -93.72967154, "iconic_taxon": "Plantae"}, {"latitude": 41.67018964, "longitude": -93.72949954, "iconic_taxon": "Plantae"}, {"latitude": 41.6695293, "longitude": -93.7294429, "iconic_taxon": "Plantae"}, {"latitude": 41.66956354, "longitude": -93.73028399, "iconic_taxon": "Plantae"}, {"latitude": 41.67, "longitude": -93.7303, "iconic_taxon": "Plantae"}, {"latitude": 41.6695968, "longitude": -93.73046505, "iconic_taxon": "Plantae"}, {"latitude": 41.66956407, "longitude": -93.73043789, "iconic_taxon": "Plantae"}, {"latitude": 41.67, "longitude": -93.7303, "iconic_taxon": "Plantae"}, {"latitude": 41.67, "longitude": -93.7303, "iconic_taxon": "Plantae"}, {"latitude": 41.67, "longitude": -93.7303, "iconic_taxon": "Plantae"}, {"latitude": 41.67, "longitude": -93.7303, "iconic_taxon": "Plantae"}, {"latitude": 41.67, "longitude": -93.7303, "iconic_taxon": "Plantae"}, {"latitude": 41.67, "longitude": -93.7303, "iconic_taxon": "Plantae"}, {"latitude": 41.67, "longitude": -93.7303, "iconic_taxon": "Plantae"}, {"latitude": 41.67, "longitude": -93.7303, "iconic_taxon": "Plantae"}, {"latitude": 41.67, "longitude": -93.7303, "iconic_taxon": "Plantae"}, {"latitude": 41.6529544, "longitude": -93.6979849, "iconic_taxon": "Fungi"}, {"latitude": 41.6228353342, "longitude": -93.7321677804, "iconic_taxon": "Plantae"}, {"latitude": 41.6229528796, "longitude": -93.7324232608, "iconic_taxon": "Plantae"}, {"latitude": 41.6231639094, "longitude": -93.734029904, "iconic_taxon": "Plantae"}, {"latitude": 41.623803511, "longitude": -93.73374 ...
